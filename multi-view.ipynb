# %%
#Install Open3D (if not installed)
import importlib.util
import sys
import subprocess

# Check if open3d is installed
package_name = 'open3d'
spec = importlib.util.find_spec(package_name)

if spec is None:
    print(f"📦 Installing {package_name}...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])
else:
    print(f"✅ {package_name} is already installed.")
# Out:
# ✅ open3d is already installed.

# %%
#This code block is useful while handling one file.
import open3d as o3d
import os
import numpy as np
import time

# Provide the full path of .off file
file_path = "/Users/sdas1/Documents/ModelNet10/bathtub/test/bathtub_0108.off"  # <-- CHANGE THIS!
object_id = os.path.splitext(os.path.basename(file_path))[0]

# Confirm the file exists
if not os.path.exists(file_path):
    print(f"❌ File not found at: {file_path}")
else:
    print(f"📂 Found file: {file_path}")


# 📁 Set path to your .off file and output directory
output_dir = "/Users/sdas1/Documents/views_manual/bathtub"
os.makedirs(output_dir, exist_ok=True)

# Load the .off file
print("🔄 Loading mesh...")
mesh = o3d.io.read_triangle_mesh(file_path)

# Check if mesh loaded successfully
if len(mesh.vertices) == 0:
    print("❌ Failed to load mesh or mesh is empty")
else:
    print(f"✅ Mesh loaded successfully with {len(mesh.vertices)} vertices and {len(mesh.triangles)} triangles")

# Normalize and center the mesh
mesh.translate(-mesh.get_center()+ np.array([0, 0, 0.1])) #np.array move the object little above the plane so that it does not trimmed
# Get the maximum extent in any dimension
max_bound = np.max(mesh.get_max_bound() - mesh.get_min_bound())
mesh.scale(1.0 / max_bound, center=mesh.get_center())

# Add colors if the mesh doesn't have them
if not mesh.has_vertex_colors():
    mesh.paint_uniform_color([0.7, 0.7, 0.7])  # Light gray color

# Compute normals for better visualization
mesh.compute_vertex_normals()

print("🎨 Setting up visualization...")

print("📸 Generating multi-view images using rotation method...")

# Create ONE visualizer and reuse it
vis = o3d.visualization.Visualizer()
vis.create_window(visible=True)
vis.add_geometry(mesh)

# Set render options
render_option = vis.get_render_option()
render_option.background_color = [1.0, 1.0, 1.0]  # White background
render_option.mesh_show_back_face = True
render_option.light_on = True

# Set initial camera position
view_control = vis.get_view_control()
view_control.set_zoom(1) #useful for zoom in and zoom out of the object.
view_control.set_front([1, 0, 0])  # Initial front direction
view_control.set_up([0, 0, 1])     # Up direction
view_control.set_lookat([0, 0, 0]) # Look at center

# Generate 12 views by rotating the object instead of moving camera
n_views = 12
rotation_angle = 360.0 / n_views  # degrees per step

for i in range(n_views):
    print(f"Generating view {i+1}/12 (rotation: {i * rotation_angle:.1f}°)...")
    
    # Update the visualization
    vis.poll_events()
    vis.update_renderer()
    
    # Small delay to ensure rendering
    time.sleep(0.2)
    
    # Capture the current view
    output_filename = os.path.join(output_dir, f"{object_id}view_{i:02d}.png")
    success = vis.capture_screen_image(output_filename)
    print(f"✅ Saved view {i+1}/12: {output_filename}")
    
    # Rotate the mesh for the next view (except for the last iteration)
    if i < n_views - 1:
        # Create rotation matrix around Z-axis
        rotation_matrix = mesh.get_rotation_matrix_from_xyz((0, 0, np.radians(rotation_angle)))
        mesh.rotate(rotation_matrix, center=[0, 0, 0])
        
        # Update the geometry in the visualizer
        vis.update_geometry(mesh)

# Close visualizer
vis.destroy_window()

print(f"🎉 Multi-view image generation completed!")
# Out:
# 📂 Found file: /Users/sdas1/Documents/ModelNet10/bathtub/test/bathtub_0108.off
# 🔄 Loading mesh...
# ✅ Mesh loaded successfully with 352 vertices and 322 triangles
# 🎨 Setting up visualization...
# 📸 Generating multi-view images using rotation method...
# Generating view 1/12 (rotation: 0.0°)...
# ✅ Saved view 1/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_00.png
# Generating view 2/12 (rotation: 30.0°)...
# ✅ Saved view 2/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_01.png
# Generating view 3/12 (rotation: 60.0°)...
# ✅ Saved view 3/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_02.png
# Generating view 4/12 (rotation: 90.0°)...
# ✅ Saved view 4/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_03.png
# Generating view 5/12 (rotation: 120.0°)...
# ✅ Saved view 5/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_04.png
# Generating view 6/12 (rotation: 150.0°)...
# ✅ Saved view 6/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_05.png
# Generating view 7/12 (rotation: 180.0°)...
# ✅ Saved view 7/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_06.png
# Generating view 8/12 (rotation: 210.0°)...
# ✅ Saved view 8/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_07.png
# Generating view 9/12 (rotation: 240.0°)...
# ✅ Saved view 9/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_08.png
# Generating view 10/12 (rotation: 270.0°)...
# ✅ Saved view 10/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_09.png
# Generating view 11/12 (rotation: 300.0°)...
# ✅ Saved view 11/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_10.png
# Generating view 12/12 (rotation: 330.0°)...
# ✅ Saved view 12/12: /Users/sdas1/Documents/views_manual/bathtub/bathtub_0108view_11.png
# 🎉 Multi-view image generation completed!

# %%
#This code block will run until you manually close the open3D window, it assumes that you are inspecting 3D shapes.
#Read the mesh
"""
    mesh = o3d.io.read_triangle_mesh(file_path)
    if mesh.is_empty():
        print("❌ Mesh is empty or failed to load. Check file format.")
    else:
        print("📏 Mesh loaded.")
        print(f"Vertices: {len(mesh.vertices)}, Triangles: {len(mesh.triangles)}")

        #Compute normals and render
        mesh.compute_vertex_normals()
        print("✅ Rendering mesh...")
        o3d.visualization.draw_geometries([mesh])
"""
# Out:
# '\n    mesh = o3d.io.read_triangle_mesh(file_path)\n    if mesh.is_empty():\n        print("❌ Mesh is empty or failed to load. Check file format.")\n    else:\n        print("📏 Mesh loaded.")\n        print(f"Vertices: {len(mesh.vertices)}, Triangles: {len(mesh.triangles)}")\n\n        #Compute normals and render\n        mesh.compute_vertex_normals()\n        print("✅ Rendering mesh...")\n        o3d.visualization.draw_geometries([mesh])\n'

# %%
#This step will load the 3D shape in a headless mode
"""
vis = o3d.visualization.Visualizer()
vis.create_window(visible=True)
vis.add_geometry(mesh)
vis.poll_events()
vis.update_renderer()
vis.capture_screen_image("temp_render.png")  # Optional save
vis.destroy_window()  # ✅ Closes automatically
"""
# Out:
# '\nvis = o3d.visualization.Visualizer()\nvis.create_window(visible=True)\nvis.add_geometry(mesh)\nvis.poll_events()\nvis.update_renderer()\nvis.capture_screen_image("temp_render.png")  # Optional save\nvis.destroy_window()  # ✅ Closes automatically\n'

# %%
#Sample Point Cloud Instead of Mesh (Optional Step for Multi-View)

#file_path = mesh.sample_points_uniformly(number_of_points=1024)
#o3d.visualization.draw_geometries([file_path])

# %%
#
# Description:
# This script processes 3D models from a specified input folder. For each model
# file (with a .off extension), it generates 12 uniformly-rotated-view images
# and saves them to a corresponding sub-directory in the output folder.
#
# The script performs the following steps for each model:
#   1. Loads the .off mesh file.
#   2. Normalizes the mesh size and centers it.
#   3. Sets up a visualizer with a white background and lighting.
#   4. Rotates the object in 12 steps around the Z-axis.
#   5. Captures a screen image at each step.
#   6. Saves the images to a dedicated folder named after the object.
#
# This version is modified to handle batch processing of all files in a folder.
#

# ==============================================================================
# 1. SETUP AND INSTALLATION
# ==============================================================================


import importlib.util
import sys
import subprocess
import os
import open3d as o3d
import numpy as np
import time

# Check if open3d is installed and install it if necessary
package_name = 'open3d'
spec = importlib.util.find_spec(package_name)

if spec is None:
    print(f"📦 Installing {package_name}...")
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])
        # Re-import after installation
        import open3d as o3d
        print(f"✅ {package_name} installed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"❌ Failed to install {package_name}. Please install it manually using 'pip install open3d'. Error: {e}")
        sys.exit(1)
else:
    print(f"✅ {package_name} is already installed.")


# ==============================================================================
# 2. CONFIGURATION & MAIN PROCESSING
# ==============================================================================

# --- USER-CONFIGURABLE PATHS ---
# 📁 Set the path to your folder containing .off files
input_dir = "/Users/sdas1/Documents/ModelNet10/bed/train/"
# 📁 Set the path where the output images will be saved
output_dir = "/Users/sdas1/Documents/views_manual/bed/train/"
# --- END OF CONFIGURATION ---

# Ensure the main output directory exists
os.makedirs(output_dir, exist_ok=True)
print(f"✅ Output will be saved to: {output_dir}")

# Get a list of all files to process
try:
    all_files = os.listdir(input_dir)
    off_files = [f for f in all_files if f.endswith(".off")]
    if not off_files:
        print(f"⚠️ No .off files found in the directory: {input_dir}")
        sys.exit(0)
    print(f"🔍 Found {len(off_files)} '.off' files to process.")
except FileNotFoundError:
    print(f"❌ Input directory not found at: {input_dir}")
    sys.exit(1)


# Create ONE visualizer instance and reuse it for all models
print("🎨 Setting up visualization window...")
vis = o3d.visualization.Visualizer()
vis.create_window(visible=True) # Set to False if you don't want to see the window

# Main loop to process each .off file
for filename in off_files:
    file_path = os.path.join(input_dir, filename)
    object_id = os.path.splitext(os.path.basename(filename))[0]
    print(f"\n{'='*60}\n🔄 Processing model: {object_id}\n{'='*60}")

    # Create a dedicated output directory for the current object's views
    object_output_dir = os.path.join(output_dir, object_id)
    os.makedirs(object_output_dir, exist_ok=True)

    # Load the .off file
    print("  📂 Loading mesh from file...")
    mesh = o3d.io.read_triangle_mesh(file_path)

    # Check if mesh loaded successfully
    if len(mesh.vertices) == 0:
        print(f"  ❌ Failed to load mesh or mesh is empty for {filename}. Skipping.")
        continue # Skip to the next file
    
    print(f"  ✅ Mesh loaded successfully with {len(mesh.vertices)} vertices and {len(mesh.triangles)} triangles.")

    # --- Mesh Preparation ---
    # Create a fresh copy to avoid carrying over rotations
    mesh_copy = o3d.geometry.TriangleMesh(mesh)
    
    # Center the mesh and move it slightly above the ground plane
    mesh_copy.translate(-mesh_copy.get_center() + np.array([0, 0, 0.1]))
    
    # Normalize the mesh to a unit cube for consistent sizing
    max_bound = np.max(mesh_copy.get_max_bound() - mesh_copy.get_min_bound())
    mesh_copy.scale(1.0 / max_bound, center=mesh_copy.get_center())
    
    # Add colors if the mesh doesn't have them
    if not mesh_copy.has_vertex_colors():
        mesh_copy.paint_uniform_color([0.7, 0.7, 0.7])  # Light gray
        
    # Compute normals for proper lighting and visualization
    mesh_copy.compute_vertex_normals()

    print("  📸 Generating multi-view images...")

    # --- Visualization Setup for Current Model ---
    vis.clear_geometries()
    vis.add_geometry(mesh_copy)

    # Set render options
    render_option = vis.get_render_option()
    render_option.background_color = np.asarray([1.0, 1.0, 1.0]) # White background
    render_option.mesh_show_back_face = True
    render_option.light_on = True

    # Set camera position
    view_control = vis.get_view_control()
    view_control.set_zoom(0.7)
    view_control.set_front([1, 0, 0])  # Initial front direction
    view_control.set_up([0, 0, 1])     # Up direction
    view_control.set_lookat([0, 0, 0]) # Look at the center of the object

    # --- View Generation Loop ---
    n_views = 12
    rotation_angle = 360.0 / n_views  # degrees per step

    for i in range(n_views):
        # Create rotation matrix around the Z-axis (up-axis)
        rotation_matrix = mesh_copy.get_rotation_matrix_from_xyz((0, 0, np.radians(i * rotation_angle)))
        # Apply the rotation
        mesh_copy.rotate(rotation_matrix, center=(0, 0, 0))
        
        # Update the geometry in the visualizer to reflect the rotation
        vis.update_geometry(mesh_copy)
        vis.poll_events()
        vis.update_renderer()
        
        # Small delay to ensure rendering is complete before capture
        time.sleep(0.1)
        
        # Capture the current view
        output_filename = os.path.join(object_output_dir, f"{object_id}_view_{i:02d}.png")
        vis.capture_screen_image(output_filename, do_render=True)
    
    print(f"  ✅ Saved {n_views} views to: {object_output_dir}")

# Clean up and close the visualizer window
vis.destroy_window()

print(f"\n{'='*60}\n🎉 All models processed successfully!\n{'='*60}")
# Out:
# ✅ open3d is already installed.
# ✅ Output will be saved to: /Users/sdas1/Documents/views_manual/bed/train/
# 🔍 Found 515 '.off' files to process.
# 🎨 Setting up visualization window...
#
# ============================================================
# 🔄 Processing model: bed_0175
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 124173 vertices and 174764 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0175
#
# ============================================================
# 🔄 Processing model: bed_0161
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 126964 vertices and 79956 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0161
#
# ============================================================
# 🔄 Processing model: bed_0149
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 11522 vertices and 13516 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0149
#
# ============================================================
# 🔄 Processing model: bed_0388
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1712 vertices and 2390 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0388
#
# ============================================================
# 🔄 Processing model: bed_0411
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 69274 vertices and 59532 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0411
#
# ============================================================
# 🔄 Processing model: bed_0377
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4308 vertices and 3633 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0377
#
# ============================================================
# 🔄 Processing model: bed_0363
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3468 vertices and 3878 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0363
#
# ============================================================
# 🔄 Processing model: bed_0405
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4379 vertices and 3968 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0405
#
# ============================================================
# 🔄 Processing model: bed_0439
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3166 vertices and 4856 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0439
#
# ============================================================
# 🔄 Processing model: bed_0203
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7918 vertices and 9458 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0203
#
# ============================================================
# 🔄 Processing model: bed_0217
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 556 vertices and 411 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0217
#
# ============================================================
# 🔄 Processing model: bed_0001
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2095 vertices and 1807 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0001
#
# ============================================================
# 🔄 Processing model: bed_0015
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3004 vertices and 3202 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0015
#
# ============================================================
# 🔄 Processing model: bed_0029
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 21344 vertices and 23802 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0029
#
# ============================================================
# 🔄 Processing model: bed_0028
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 15556 vertices and 17694 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0028
#
# ============================================================
# 🔄 Processing model: bed_0014
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 13036 vertices and 21302 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0014
#
# ============================================================
# 🔄 Processing model: bed_0216
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 659 vertices and 848 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0216
#
# ============================================================
# 🔄 Processing model: bed_0202
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 8688 vertices and 13600 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0202
#
# ============================================================
# 🔄 Processing model: bed_0438
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 180 vertices and 132 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0438
#
# ============================================================
# 🔄 Processing model: bed_0362
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5446 vertices and 3610 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0362
#
# ============================================================
# 🔄 Processing model: bed_0404
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 82392 vertices and 127294 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0404
#
# ============================================================
# 🔄 Processing model: bed_0410
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1166 vertices and 1780 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0410
#
# ============================================================
# 🔄 Processing model: bed_0376
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3854 vertices and 6548 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0376
#
# ============================================================
# 🔄 Processing model: bed_0389
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7309 vertices and 13264 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0389
#
# ============================================================
# 🔄 Processing model: bed_0148
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 31096 vertices and 10348 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0148
#
# ============================================================
# 🔄 Processing model: bed_0160
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3410 vertices and 5518 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0160
#
# ============================================================
# 🔄 Processing model: bed_0174
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2694 vertices and 3982 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0174
#
# ============================================================
# 🔄 Processing model: bed_0189
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 20684 vertices and 38880 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0189
#
# ============================================================
# 🔄 Processing model: bed_0162
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 404 vertices and 372 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0162
#
# ============================================================
# 🔄 Processing model: bed_0176
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 17121 vertices and 24998 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0176
#
# ============================================================
# 🔄 Processing model: bed_0406
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 10736 vertices and 19776 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0406
#
# ============================================================
# 🔄 Processing model: bed_0360
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1100 vertices and 752 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0360
#
# ============================================================
# 🔄 Processing model: bed_0374
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2002 vertices and 2273 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0374
#
# ============================================================
# 🔄 Processing model: bed_0412
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 321 vertices and 304 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0412
#
# ============================================================
# 🔄 Processing model: bed_0348
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5972 vertices and 6640 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0348
#
# ============================================================
# 🔄 Processing model: bed_0214
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 694 vertices and 624 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0214
#
# ============================================================
# 🔄 Processing model: bed_0200
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 480 vertices and 414 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0200
#
# ============================================================
# 🔄 Processing model: bed_0228
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 108041 vertices and 141508 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0228
#
# ============================================================
# 🔄 Processing model: bed_0016
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3176 vertices and 3060 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0016
#
# ============================================================
# 🔄 Processing model: bed_0002
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 22627 vertices and 35299 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0002
#
# ============================================================
# 🔄 Processing model: bed_0003
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2644 vertices and 2440 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0003
#
# ============================================================
# 🔄 Processing model: bed_0017
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5161 vertices and 4413 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0017
#
# ============================================================
# 🔄 Processing model: bed_0229
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4154 vertices and 7994 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0229
#
# ============================================================
# 🔄 Processing model: bed_0201
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 269 vertices and 180 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0201
#
# ============================================================
# 🔄 Processing model: bed_0215
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1890 vertices and 2438 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0215
#
# ============================================================
# 🔄 Processing model: bed_0349
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 8706 vertices and 9438 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0349
#
# ============================================================
# 🔄 Processing model: bed_0375
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 73701 vertices and 28424 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0375
#
# ============================================================
# 🔄 Processing model: bed_0413
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1165 vertices and 1081 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0413
#
# ============================================================
# 🔄 Processing model: bed_0407
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7756 vertices and 10088 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0407
#
# ============================================================
# 🔄 Processing model: bed_0361
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7813 vertices and 11084 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0361
#
# ============================================================
# 🔄 Processing model: bed_0177
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 480 vertices and 560 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0177
#
# ============================================================
# 🔄 Processing model: bed_0163
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1244 vertices and 1914 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0163
#
# ============================================================
# 🔄 Processing model: bed_0188
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 20685 vertices and 24445 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0188
#
# ============================================================
# 🔄 Processing model: bed_0198
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4584 vertices and 4228 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0198
#
# ============================================================
# 🔄 Processing model: bed_0167
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1468 vertices and 1000 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0167
#
# ============================================================
# 🔄 Processing model: bed_0173
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7328 vertices and 5847 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0173
#
# ============================================================
# 🔄 Processing model: bed_0359
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 354 vertices and 366 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0359
#
# ============================================================
# 🔄 Processing model: bed_0365
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 760 vertices and 660 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0365
#
# ============================================================
# 🔄 Processing model: bed_0403
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 861 vertices and 800 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0403
#
# ============================================================
# 🔄 Processing model: bed_0417
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2822 vertices and 4042 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0417
#
# ============================================================
# 🔄 Processing model: bed_0371
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2814 vertices and 4823 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0371
#
# ============================================================
# 🔄 Processing model: bed_0239
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 8544 vertices and 15968 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0239
#
# ============================================================
# 🔄 Processing model: bed_0211
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5881 vertices and 9404 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0211
#
# ============================================================
# 🔄 Processing model: bed_0205
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 393 vertices and 366 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0205
#
# ============================================================
# 🔄 Processing model: bed_0013
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 523 vertices and 492 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0013
#
# ============================================================
# 🔄 Processing model: bed_0007
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 15044 vertices and 27338 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0007
#
# ============================================================
# 🔄 Processing model: bed_0006
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 29380 vertices and 10045 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0006
#
# ============================================================
# 🔄 Processing model: bed_0012
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 13945 vertices and 14572 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0012
#
# ============================================================
# 🔄 Processing model: bed_0204
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4792 vertices and 2216 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0204
#
# ============================================================
# 🔄 Processing model: bed_0210
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2272 vertices and 1692 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0210
#
# ============================================================
# 🔄 Processing model: bed_0238
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1404 vertices and 1238 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0238
#
# ============================================================
# 🔄 Processing model: bed_0416
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3103 vertices and 5253 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0416
#
# ============================================================
# 🔄 Processing model: bed_0370
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2650 vertices and 4456 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0370
#
# ============================================================
# 🔄 Processing model: bed_0364
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1028 vertices and 690 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0364
#
# ============================================================
# 🔄 Processing model: bed_0402
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 10323 vertices and 11114 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0402
#
# ============================================================
# 🔄 Processing model: bed_0358
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 353 vertices and 334 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0358
#
# ============================================================
# 🔄 Processing model: bed_0172
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2475 vertices and 3030 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0172
#
# ============================================================
# 🔄 Processing model: bed_0166
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 84080 vertices and 122016 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0166
#
# ============================================================
# 🔄 Processing model: bed_0199
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5372 vertices and 4476 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0199
#
# ============================================================
# 🔄 Processing model: bed_0158
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3527 vertices and 4131 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0158
#
# ============================================================
# 🔄 Processing model: bed_0170
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1024 vertices and 1346 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0170
#
# ============================================================
# 🔄 Processing model: bed_0164
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1938 vertices and 3102 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0164
#
# ============================================================
# 🔄 Processing model: bed_0399
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 427 vertices and 303 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0399
#
# ============================================================
# 🔄 Processing model: bed_0428
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5560 vertices and 4544 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0428
#
# ============================================================
# 🔄 Processing model: bed_0372
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 6719 vertices and 9338 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0372
#
# ============================================================
# 🔄 Processing model: bed_0414
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 19681 vertices and 24001 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0414
#
# ============================================================
# 🔄 Processing model: bed_0400
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 13235 vertices and 16885 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0400
#
# ============================================================
# 🔄 Processing model: bed_0366
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4163 vertices and 3537 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0366
#
# ============================================================
# 🔄 Processing model: bed_0206
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 822 vertices and 674 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0206
#
# ============================================================
# 🔄 Processing model: bed_0212
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2656 vertices and 3674 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0212
#
# ============================================================
# 🔄 Processing model: bed_0038
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 16610 vertices and 31920 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0038
#
# ============================================================
# 🔄 Processing model: bed_0004
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2035 vertices and 2200 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0004
#
# ============================================================
# 🔄 Processing model: bed_0010
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 11359 vertices and 9184 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0010
#
# ============================================================
# 🔄 Processing model: bed_0011
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5440 vertices and 9063 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0011
#
# ============================================================
# 🔄 Processing model: bed_0005
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4320 vertices and 6761 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0005
#
# ============================================================
# 🔄 Processing model: bed_0039
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1591 vertices and 1228 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0039
#
# ============================================================
# 🔄 Processing model: bed_0213
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 132 vertices and 84 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0213
#
# ============================================================
# 🔄 Processing model: bed_0207
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 750 vertices and 662 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0207
#
# ============================================================
# 🔄 Processing model: bed_0401
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 9171 vertices and 6582 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0401
#
# ============================================================
# 🔄 Processing model: bed_0367
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1025 vertices and 554 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0367
#
# ============================================================
# 🔄 Processing model: bed_0373
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1211 vertices and 902 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0373
#
# ============================================================
# 🔄 Processing model: bed_0415
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1109 vertices and 862 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0415
#
# ============================================================
# 🔄 Processing model: bed_0429
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 322 vertices and 306 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0429
#
# ============================================================
# 🔄 Processing model: bed_0398
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3368 vertices and 5376 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0398
#
# ============================================================
# 🔄 Processing model: bed_0165
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 13190 vertices and 15376 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0165
#
# ============================================================
# 🔄 Processing model: bed_0171
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 52646 vertices and 104726 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0171
#
# ============================================================
# 🔄 Processing model: bed_0159
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 16306 vertices and 28408 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0159
#
# ============================================================
# 🔄 Processing model: bed_0116
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2077 vertices and 2968 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0116
#
# ============================================================
# 🔄 Processing model: bed_0102
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 296 vertices and 222 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0102
#
# ============================================================
# 🔄 Processing model: bed_0499
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1212 vertices and 616 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0499
#
# ============================================================
# 🔄 Processing model: bed_0314
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3984 vertices and 3654 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0314
#
# ============================================================
# 🔄 Processing model: bed_0472
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 117684 vertices and 88193 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0472
#
# ============================================================
# 🔄 Processing model: bed_0466
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 33120 vertices and 52284 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0466
#
# ============================================================
# 🔄 Processing model: bed_0300
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4188 vertices and 8008 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0300
#
# ============================================================
# 🔄 Processing model: bed_0328
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 476 vertices and 368 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0328
#
# ============================================================
# 🔄 Processing model: bed_0260
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 28256 vertices and 49073 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0260
#
# ============================================================
# 🔄 Processing model: bed_0506
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2550 vertices and 3584 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0506
#
# ============================================================
# 🔄 Processing model: bed_0512
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 14267 vertices and 26873 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0512
#
# ============================================================
# 🔄 Processing model: bed_0274
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 671 vertices and 1045 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0274
#
# ============================================================
# 🔄 Processing model: bed_0248
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 13717 vertices and 8856 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0248
#
# ============================================================
# 🔄 Processing model: bed_0089
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3293 vertices and 4428 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0089
#
# ============================================================
# 🔄 Processing model: bed_0062
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 462 vertices and 308 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0062
#
# ============================================================
# 🔄 Processing model: bed_0076
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 8574 vertices and 10590 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0076
#
# ============================================================
# 🔄 Processing model: bed_0077
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 30229 vertices and 28649 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0077
#
# ============================================================
# 🔄 Processing model: bed_0063
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 4233 vertices and 3607 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0063
#
# ============================================================
# 🔄 Processing model: bed_0088
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 5643 vertices and 7295 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0088
#
# ============================================================
# 🔄 Processing model: bed_0249
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 740 vertices and 496 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0249
#
# ============================================================
# 🔄 Processing model: bed_0513
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3582 vertices and 2649 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0513
#
# ============================================================
# 🔄 Processing model: bed_0275
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 366 vertices and 318 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0275
#
# ============================================================
# 🔄 Processing model: bed_0261
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1866 vertices and 2672 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0261
#
# ============================================================
# 🔄 Processing model: bed_0507
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 11582 vertices and 17760 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0507
#
# ============================================================
# 🔄 Processing model: bed_0329
# ...
#   ✅ Mesh loaded successfully with 1823 vertices and 1497 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0351
#
# ============================================================
# 🔄 Processing model: bed_0345
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 10738 vertices and 16474 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0345
#
# ============================================================
# 🔄 Processing model: bed_0423
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 36622 vertices and 16179 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0423
#
# ============================================================
# 🔄 Processing model: bed_0379
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 552 vertices and 472 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0379
#
# ============================================================
# 🔄 Processing model: bed_0392
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 750 vertices and 644 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0392
#
# ============================================================
# 🔄 Processing model: bed_0386
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 11060 vertices and 5854 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0386
#
# ============================================================
# 🔄 Processing model: bed_0153
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7670 vertices and 7976 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0153
#
# ============================================================
# 🔄 Processing model: bed_0147
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7372 vertices and 10624 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0147
#
# ============================================================
# 🔄 Processing model: bed_0190
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 453 vertices and 470 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0190
#
# ============================================================
# 🔄 Processing model: bed_0184
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1938 vertices and 2544 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0184
#
# ============================================================
# 🔄 Processing model: bed_0192
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3208 vertices and 5120 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0192
#
# ============================================================
# 🔄 Processing model: bed_0186
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 34395 vertices and 47361 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0186
#
# ============================================================
# 🔄 Processing model: bed_0179
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2817 vertices and 3870 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0179
#
# ============================================================
# 🔄 Processing model: bed_0151
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 524 vertices and 324 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0151
#
# ============================================================
# 🔄 Processing model: bed_0145
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 312 vertices and 274 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0145
#
# ============================================================
# 🔄 Processing model: bed_0390
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1425 vertices and 1954 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0390
#
# ============================================================
# 🔄 Processing model: bed_0384
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2806 vertices and 2376 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0384
#
# ============================================================
# 🔄 Processing model: bed_0409
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 104800 vertices and 208716 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0409
#
# ============================================================
# 🔄 Processing model: bed_0353
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1196 vertices and 1386 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0353
#
# ============================================================
# 🔄 Processing model: bed_0435
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 938 vertices and 866 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0435
#
# ============================================================
# 🔄 Processing model: bed_0421
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1271 vertices and 980 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0421
#
# ============================================================
# 🔄 Processing model: bed_0347
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 710 vertices and 732 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0347
#
# ============================================================
# 🔄 Processing model: bed_0227
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 22163 vertices and 29496 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0227
#
# ============================================================
# 🔄 Processing model: bed_0233
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 232 vertices and 116 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0233
#
# ============================================================
# 🔄 Processing model: bed_0019
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 935 vertices and 838 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0019
#
# ============================================================
# 🔄 Processing model: bed_0025
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 29546 vertices and 58671 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0025
#
# ============================================================
# 🔄 Processing model: bed_0031
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1729 vertices and 1510 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0031
#
# ============================================================
# 🔄 Processing model: bed_0030
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3474 vertices and 3230 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0030
#
# ============================================================
# 🔄 Processing model: bed_0024
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 7378 vertices and 8103 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0024
#
# ============================================================
# 🔄 Processing model: bed_0018
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 3138 vertices and 4847 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0018
#
# ============================================================
# 🔄 Processing model: bed_0232
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 11656 vertices and 12369 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0232
#
# ============================================================
# 🔄 Processing model: bed_0226
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 133 vertices and 114 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0226
#
# ============================================================
# 🔄 Processing model: bed_0420
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 8020 vertices and 13126 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0420
#
# ============================================================
# 🔄 Processing model: bed_0346
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1870 vertices and 2602 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0346
#
# ============================================================
# 🔄 Processing model: bed_0352
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1683 vertices and 1980 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0352
#
# ============================================================
# 🔄 Processing model: bed_0434
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2353 vertices and 1557 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0434
#
# ============================================================
# 🔄 Processing model: bed_0408
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 24252 vertices and 32659 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0408
#
# ============================================================
# 🔄 Processing model: bed_0385
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 30662 vertices and 56689 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0385
#
# ============================================================
# 🔄 Processing model: bed_0391
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1303 vertices and 1105 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0391
#
# ============================================================
# 🔄 Processing model: bed_0144
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 384 vertices and 192 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0144
#
# ============================================================
# 🔄 Processing model: bed_0150
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 172 vertices and 129 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0150
#
# ============================================================
# 🔄 Processing model: bed_0178
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 2792 vertices and 2317 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0178
#
# ============================================================
# 🔄 Processing model: bed_0187
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 14424 vertices and 27820 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0187
#
# ============================================================
# 🔄 Processing model: bed_0193
# ============================================================
#   📂 Loading mesh from file...
#   ✅ Mesh loaded successfully with 1264 vertices and 750 triangles.
#   📸 Generating multi-view images...
#   ✅ Saved 12 views to: /Users/sdas1/Documents/views_manual/bed/train/bed_0193
#
# ============================================================
# 🎉 All models processed successfully!
# ============================================================
